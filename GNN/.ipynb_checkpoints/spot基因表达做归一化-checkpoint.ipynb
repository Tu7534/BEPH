# %%
cd /data/home/wangzz_group/zhaipengyuan/BEPH-main/DATA_DIRECTORY/kz_data/Raw_Data/
# Out:
# /data/home/wangzz_group/zhaipengyuan/BEPH-main/DATA_DIRECTORY/kz_data/Raw_Data
# /data/home/wangzz_group/zhaipengyuan/.conda/envs/BEPH/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## 对原始数据基因表达做Log1p Normalization（对数加一归一化）

# %%
import scanpy as sc
import os
import glob
from pathlib import Path

# ================= 配置区域 =================
# 输入文件夹路径
input_folder = "h5ad_files"
# 输出文件夹路径
output_folder = "Log1p"

# 质量控制参数 (根据你的数据情况微调)
MIN_COUNTS = 100  # 一个 Spot 至少要有 100 个 Count，否则视为垃圾点剔除
MIN_GENES = 10    # 一个 Spot 至少要检测到 10 个基因

# ================= 主程序 =================

# 1. 确保输出文件夹存在，不存在则创建
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"已创建输出文件夹: {output_folder}")
else:
    print(f"输出文件夹已存在: {output_folder}")

# 2. 获取所有 h5ad 文件路径
# 支持 .h5ad 后缀
files = glob.glob(os.path.join(input_folder, "*.h5ad"))

print(f"共发现 {len(files)} 个 h5ad 文件，准备开始处理...\n")

for i, file_path in enumerate(files):
    file_name = os.path.basename(file_path)
    print(f"[{i+1}/{len(files)}] 正在处理: {file_name} ...")
    
    try:
        # --- A. 读取数据 ---
        adata = sc.read_h5ad(file_path)
        original_n_obs = adata.n_obs
        
        # --- B. 质量控制 (QC) - 关键步骤 ---
        # 过滤掉质量极差的点，防止 Log1p 后出现异常高值
        sc.pp.filter_cells(adata, min_counts=MIN_COUNTS)
        sc.pp.filter_cells(adata, min_genes=MIN_GENES)
        
        # 打印过滤信息
        filtered_n_obs = adata.n_obs
        print(f"    - QC过滤: 移除 {original_n_obs - filtered_n_obs} 个低质量 Spots (剩余 {filtered_n_obs})")
        
        # 如果过滤后没点了，跳过
        if filtered_n_obs == 0:
            print("    - [警告] 该文件过滤后为空，跳过保存。")
            continue

        # --- C. 标准化处理 ---
        # 1. 总计数归一化 (Normalize to CPM/TPM like)
        sc.pp.normalize_total(adata, target_sum=1e4)
        
        # 2. Log1p 变换
        sc.pp.log1p(adata)
        
        # (可选) 可以在这里加入找高变基因，如果你希望保存的文件里带有高变基因标记
        sc.pp.highly_variable_genes(adata, n_top_genes=3000, flavor="seurat")
        adata = adata[:, adata.var['highly_variable']]
        # --- D. 保存文件 ---
        # 构造输出路径，保持文件名不变
        output_path = os.path.join(output_folder, file_name)
        
        # 保存 (开启压缩可以减小文件体积)
        adata.write(output_path, compression="gzip")
        print(f"    - 已保存至: {output_path}")
        
    except Exception as e:
        print(f"    - [错误] 处理文件 {file_name} 时出错: {e}")

print("\n" + "="*30)
print("所有文件处理完成！")
# Out:
# 输出文件夹已存在: Log1p
# 共发现 65 个 h5ad 文件，准备开始处理...
#
# [1/65] 正在处理: GSM5924030.h5ad ...
#     - QC过滤: 移除 7 个低质量 Spots (剩余 4503)
#     - 已保存至: Log1p/GSM5924030.h5ad
# [2/65] 正在处理: GSM6177609.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2493)
#     - 已保存至: Log1p/GSM6177609.h5ad
# [3/65] 正在处理: GSM5924035.h5ad ...
#     - QC过滤: 移除 10 个低质量 Spots (剩余 4938)
#     - 已保存至: Log1p/GSM5924035.h5ad
# [4/65] 正在处理: GSM6177599.h5ad ...
#     - QC过滤: 移除 3 个低质量 Spots (剩余 2381)
#     - 已保存至: Log1p/GSM6177599.h5ad
# [5/65] 正在处理: GSM6177614.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1762)
#     - 已保存至: Log1p/GSM6177614.h5ad
# [6/65] 正在处理: GSM5924046.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1949)
#     - 已保存至: Log1p/GSM5924046.h5ad
# [7/65] 正在处理: GSM5621966.h5ad ...
#     - QC过滤: 移除 4 个低质量 Spots (剩余 471)
#     - 已保存至: Log1p/GSM5621966.h5ad
# [8/65] 正在处理: GSM6177624.h5ad ...
#     - QC过滤: 移除 26 个低质量 Spots (剩余 3013)
#     - 已保存至: Log1p/GSM6177624.h5ad
# [9/65] 正在处理: GSM5833531.h5ad ...
#     - QC过滤: 移除 1 个低质量 Spots (剩余 1055)
#     - 已保存至: Log1p/GSM5833531.h5ad
# [10/65] 正在处理: GSM5833534.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2891)
#     - 已保存至: Log1p/GSM5833534.h5ad
# [11/65] 正在处理: 151673.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 3639)
#     - 已保存至: Log1p/151673.h5ad
# [12/65] 正在处理: GSM5621974.h5ad ...
#     - QC过滤: 移除 21 个低质量 Spots (剩余 2533)
#     - 已保存至: Log1p/GSM5621974.h5ad
# [13/65] 正在处理: GSM5924032.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 3829)
#     - 已保存至: Log1p/GSM5924032.h5ad
# [14/65] 正在处理: GSM6177623.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1351)
#     - 已保存至: Log1p/GSM6177623.h5ad
# [15/65] 正在处理: GSM5924053.h5ad ...
#     - QC过滤: 移除 1 个低质量 Spots (剩余 1083)
#     - 已保存至: Log1p/GSM5924053.h5ad
# [16/65] 正在处理: GSM5621971.h5ad ...
#     - QC过滤: 移除 4 个低质量 Spots (剩余 529)
#     - 已保存至: Log1p/GSM5621971.h5ad
# [17/65] 正在处理: ColorectalCancer_10x.h5ad ...
#     - QC过滤: 移除 320 个低质量 Spots (剩余 4672)
#     - 已保存至: Log1p/ColorectalCancer_10x.h5ad
# [18/65] 正在处理: GSM5924039.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 4940)
#     - 已保存至: Log1p/GSM5924039.h5ad
# [19/65] 正在处理: GSM5924036.h5ad ...
#     - QC过滤: 移除 3 个低质量 Spots (剩余 4912)
#     - 已保存至: Log1p/GSM5924036.h5ad
# [20/65] 正在处理: GSM5621978.h5ad ...
#     - QC过滤: 移除 3 个低质量 Spots (剩余 3044)
#     - 已保存至: Log1p/GSM5621978.h5ad
# [21/65] 正在处理: GSM5924050.h5ad ...
#     - QC过滤: 移除 3 个低质量 Spots (剩余 1346)
#     - 已保存至: Log1p/GSM5924050.h5ad
# [22/65] 正在处理: GSM5833538.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2171)
#     - 已保存至: Log1p/GSM5833538.h5ad
# [23/65] 正在处理: GSM5833528.h5ad ...
#     - QC过滤: 移除 58 个低质量 Spots (剩余 4279)
#     - 已保存至: Log1p/GSM5833528.h5ad
# [24/65] 正在处理: GSM6177601.h5ad ...
#     - QC过滤: 移除 350 个低质量 Spots (剩余 1513)
#     - 已保存至: Log1p/GSM6177601.h5ad
# [25/65] 正在处理: GSM5924049.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1186)
#     - 已保存至: Log1p/GSM5924049.h5ad
# [26/65] 正在处理: GSM5621967.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 469)
#     - 已保存至: Log1p/GSM5621967.h5ad
# [27/65] 正在处理: GSM5924041.h5ad ...
#     - QC过滤: 移除 6 个低质量 Spots (剩余 4353)
#     - 已保存至: Log1p/GSM5924041.h5ad
# [28/65] 正在处理: GSM5924034.h5ad ...
#     - QC过滤: 移除 6 个低质量 Spots (剩余 4854)
#     - 已保存至: Log1p/GSM5924034.h5ad
# [29/65] 正在处理: GSM5924045.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1696)
#     - 已保存至: Log1p/GSM5924045.h5ad
# [30/65] 正在处理: GSM5924052.h5ad ...
#     - QC过滤: 移除 1 个低质量 Spots (剩余 2579)
#     - 已保存至: Log1p/GSM5924052.h5ad
# [31/65] 正在处理: GSM5621975.h5ad ...
#     - QC过滤: 移除 49 个低质量 Spots (剩余 2453)
#     - 已保存至: Log1p/GSM5621975.h5ad
# [32/65] 正在处理: GSM5621965.h5ad ...
#     - QC过滤: 移除 6 个低质量 Spots (剩余 407)
#     - 已保存至: Log1p/GSM5621965.h5ad
# [33/65] 正在处理: GSM5621973.h5ad ...
#     - QC过滤: 移除 20 个低质量 Spots (剩余 2379)
#     - 已保存至: Log1p/GSM5621973.h5ad
# [34/65] 正在处理: GSM5924038.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 3206)
#     - 已保存至: Log1p/GSM5924038.h5ad
# [35/65] 正在处理: GSM5833533.h5ad ...
#     - QC过滤: 移除 45 个低质量 Spots (剩余 4719)
#     - 已保存至: Log1p/GSM5833533.h5ad
# [36/65] 正在处理: GSM5924047.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2374)
#     - 已保存至: Log1p/GSM5924047.h5ad
# [37/65] 正在处理: GSM6177612.h5ad ...
#     - QC过滤: 移除 2 个低质量 Spots (剩余 1659)
#     - 已保存至: Log1p/GSM6177612.h5ad
# [38/65] 正在处理: GSM5924048.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1678)
#     - 已保存至: Log1p/GSM5924048.h5ad
# [39/65] 正在处理: GSM5924033.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 4975)
#     - 已保存至: Log1p/GSM5924033.h5ad
# [40/65] 正在处理: GSM5924043.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1439)
#     - 已保存至: Log1p/GSM5924043.h5ad
# [41/65] 正在处理: GSM5621976.h5ad ...
#     - QC过滤: 移除 6 个低质量 Spots (剩余 2210)
#     - 已保存至: Log1p/GSM5621976.h5ad
# [42/65] 正在处理: GSM6177607.h5ad ...
#     - QC过滤: 移除 5 个低质量 Spots (剩余 2619)
#     - 已保存至: Log1p/GSM6177607.h5ad
# [43/65] 正在处理: GSM6177625.h5ad ...
#     - QC过滤: 移除 30 个低质量 Spots (剩余 2526)
#     - 已保存至: Log1p/GSM6177625.h5ad
# [44/65] 正在处理: GSM5833537.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2203)
#     - 已保存至: Log1p/GSM5833537.h5ad
# [45/65] 正在处理: GSM5924031.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 4755)
#     - 已保存至: Log1p/GSM5924031.h5ad
# [46/65] 正在处理: GSM5621969.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 444)
#     - 已保存至: Log1p/GSM5621969.h5ad
# [47/65] 正在处理: GSM5833536.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2540)
#     - 已保存至: Log1p/GSM5833536.h5ad
# [48/65] 正在处理: GSM5621968.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 416)
#     - 已保存至: Log1p/GSM5621968.h5ad
# [49/65] 正在处理: GSM5924037.h5ad ...
#     - QC过滤: 移除 36 个低质量 Spots (剩余 3549)
#     - 已保存至: Log1p/GSM5924037.h5ad
# [50/65] 正在处理: GSM5833529.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2305)
#     - 已保存至: Log1p/GSM5833529.h5ad
# [51/65] 正在处理: GSM6177603.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 2346)
#     - 已保存至: Log1p/GSM6177603.h5ad
# [52/65] 正在处理: GSM6177618.h5ad ...
#     - QC过滤: 移除 21 个低质量 Spots (剩余 1768)
#     - 已保存至: Log1p/GSM6177618.h5ad
# [53/65] 正在处理: GSM5924040.h5ad ...
#     - QC过滤: 移除 3 个低质量 Spots (剩余 4559)
#     - 已保存至: Log1p/GSM5924040.h5ad
# [54/65] 正在处理: GSM5924051.h5ad ...
#     - QC过滤: 移除 4 个低质量 Spots (剩余 2003)
#     - 已保存至: Log1p/GSM5924051.h5ad
# [55/65] 正在处理: LungCancer_10x.h5ad ...
#     - QC过滤: 移除 577 个低质量 Spots (剩余 4415)
#     - 已保存至: Log1p/LungCancer_10x.h5ad
# [56/65] 正在处理: GSM5833530.h5ad ...
#     - QC过滤: 移除 1 个低质量 Spots (剩余 1062)
#     - 已保存至: Log1p/GSM5833530.h5ad
# [57/65] 正在处理: GSM5833532.h5ad ...
#     - QC过滤: 移除 5 个低质量 Spots (剩余 2123)
#     - 已保存至: Log1p/GSM5833532.h5ad
# [58/65] 正在处理: ProstateAcinarCancer_10x.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 4992)
#     - 已保存至: Log1p/ProstateAcinarCancer_10x.h5ad
# [59/65] 正在处理: GSM5621970.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 439)
#     - 已保存至: Log1p/GSM5621970.h5ad
# [60/65] 正在处理: GSM5621972.h5ad ...
#     - QC过滤: 移除 3 个低质量 Spots (剩余 2533)
#     - 已保存至: Log1p/GSM5621972.h5ad
# [61/65] 正在处理: GSM5924044.h5ad ...
#     - QC过滤: 移除 4 个低质量 Spots (剩余 1979)
#     - 已保存至: Log1p/GSM5924044.h5ad
# [62/65] 正在处理: GSM5924042.h5ad ...
#     - QC过滤: 移除 0 个低质量 Spots (剩余 1451)
#     - 已保存至: Log1p/GSM5924042.h5ad
# [63/65] 正在处理: GSM5833535.h5ad ...
#     - QC过滤: 移除 2 个低质量 Spots (剩余 1773)
#     - 已保存至: Log1p/GSM5833535.h5ad
# [64/65] 正在处理: GSM6177617.h5ad ...
#     - QC过滤: 移除 2 个低质量 Spots (剩余 1659)
#     - 已保存至: Log1p/GSM6177617.h5ad
# [65/65] 正在处理: GSM5621977.h5ad ...
#     - QC过滤: 移除 12 个低质量 Spots (剩余 3093)
#     - 已保存至: Log1p/GSM5621977.h5ad
#
# ==============================
# 所有文件处理完成！
