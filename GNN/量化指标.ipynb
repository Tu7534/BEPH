# %%
### 代码把 Silhouette Score 跑出来（如果没有 Ground Truth）。如果有 Ground Truth，把 ARI 跑出来。

# %% [markdown]
# ### Silhouette Score (轮廓系数)

# %%
"""
作用：评价聚类的致密程度和分离程度。即“类内越紧密，类间越疏远”越好。
范围：[-1, 1]。分值越高越好。
用途：证明你的 Embedding 真的把不同的组织区分开了。
"""
# Out:
# '\n作用：评价聚类的致密程度和分离程度。即“类内越紧密，类间越疏远”越好。\n范围：[-1, 1]。分值越高越好。\n用途：证明你的 Embedding 真的把不同的组织区分开了。\n'
